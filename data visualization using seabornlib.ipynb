# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # univariant "one variable" data visualization

# %%
sns.stripplot(y="tip", data=df,jitter=True)
plt.ylabel("tip ($)")
plt.show()

# %%
plt.figure(figsize=(8,7))
sns.boxplot(x="size", y="tip", data=df,)
plt.ylabel("tip ($)")
plt.show()

# %%
plt.figure(figsize=(8,7))
sns.boxplot(x="time", y="tip", data=df,)
plt.ylabel("tip ($)")
plt.show()

# %%
sns.boxplot(x="day", y="tip", hue="sex", data=df)
plt.ylabel("tip ($)")
plt.show()

# %%
sns.stripplot(x="day", y="tip",hue="sex", data=df,jitter=True)
plt.ylabel("tip ($)")
plt.show()

# %%
plt.figure(figsize=(8,7))
sns.boxplot(x="smoker", y="tip", data=df,)
plt.ylabel("tip ($)")
plt.show()

# %%
sns.violinplot(x="sex",y="total_bill",data=df)
plt.title("comparing male and female paying total bill")
plt.show()

# %% [markdown]
# 1.comparing people visiting normal days giving tips and weekend days mostly saturday observed giving more TIPS
# 2.time is affecting tips? __ we have observed that in dinner peoples give more tips
# 3.smoker is affecting tips? __ we observed that smoker meadian is little higher but No smoker observed giving more tips
